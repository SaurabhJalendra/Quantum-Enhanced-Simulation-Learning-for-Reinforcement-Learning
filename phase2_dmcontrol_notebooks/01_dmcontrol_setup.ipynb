# %% [markdown]
# # Phase 2: DMControl Suite Setup
#
# **Environment setup and validation for DeepMind Control Suite experiments.**
#
# This notebook sets up Walker-walk, Cheetah-run, and Reacher environments.

# %% [markdown]
# ---
# ## 1. Imports and Dependencies

# %%
"""
Cell: Imports and Configuration
"""
import sys
from pathlib import Path

# Add project root to path
PROJECT_ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import numpy as np
import torch
from dm_control import suite

from utils import set_seed, get_device, MetricLogger, COLORS

SEED = 42
set_seed(SEED)
DEVICE = get_device()
print(f"Device: {DEVICE}")

# %% [markdown]
# ---
# ## 2. DMControl Environment Wrappers
#
# Wrapper classes for DMControl Suite environments.

# %%
# TODO: Implement

# %% [markdown]
# ---
# ## 3. Walker-walk Environment
#
# Setup and validation of Walker-walk environment.

# %%
# TODO: Implement

# %% [markdown]
# ---
# ## 4. Cheetah-run Environment
#
# Setup and validation of Cheetah-run environment.

# %%
# TODO: Implement

# %% [markdown]
# ---
# ## 5. Reacher Environments
#
# Setup and validation of Reacher-easy and Reacher-hard.

# %%
# TODO: Implement

# %% [markdown]
# ---
# ## 6. Data Collection Utilities
#
# Functions for collecting trajectories from DMControl environments.

# %%
# TODO: Implement

# %% [markdown]
# ---
# ## 7. Environment Validation
#
# Verify all environments work correctly.

# %%
# TODO: Implement
