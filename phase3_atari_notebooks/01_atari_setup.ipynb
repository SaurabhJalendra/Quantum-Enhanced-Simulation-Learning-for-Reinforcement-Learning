# %% [markdown]
# # Phase 3: Atari Environment Setup
#
# **Environment setup for Atari visual RL experiments.**
#
# This notebook sets up Pong and Breakout environments with image preprocessing.

# %% [markdown]
# ---
# ## 1. Imports and Dependencies

# %%
"""
Cell: Imports and Configuration
"""
import sys
from pathlib import Path

# Add project root to path
PROJECT_ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import numpy as np
import torch
import gymnasium as gym

from utils import set_seed, get_device, MetricLogger, COLORS

SEED = 42
set_seed(SEED)
DEVICE = get_device()
print(f"Device: {DEVICE}")

# %% [markdown]
# ---
# ## 2. Atari Environment Wrappers
#
# Wrappers for frame preprocessing (84x84, grayscale, stacking).

# %%
# TODO: Implement

# %% [markdown]
# ---
# ## 3. CNN Encoder Architecture
#
# Convolutional encoder for image observations.

# %%
# TODO: Implement

# %% [markdown]
# ---
# ## 4. Pong Environment Setup
#
# Setup and validation of Pong-v5.

# %%
# TODO: Implement

# %% [markdown]
# ---
# ## 5. Breakout Environment Setup
#
# Setup and validation of Breakout-v5.

# %%
# TODO: Implement

# %% [markdown]
# ---
# ## 6. Visual Data Collection
#
# Functions for collecting image-based trajectories.

# %%
# TODO: Implement

# %% [markdown]
# ---
# ## 7. Environment Validation
#
# Verify all environments work correctly.

# %%
# TODO: Implement
